# %%
from pyniche.data.yolo.API import YOLO_API
from dotenv import load_dotenv
import os
load_dotenv(".env")
DIR_DATA_STUDY2 = os.getenv("DIR_DATA_STUDY2")

# %%
api = YOLO_API(DIR_DATA_STUDY2)
# Out:
# Loaded 320 images from test_4x10
# Loaded 32 images from test_2x2
# Loaded 128 images from test_4x4
# Loaded 1597 images from train
# Loaded 298 images from val
# Loaded 640 images from test_8x10
# Loaded 8 images from test
# Loaded 64 images from test_2x4

# %%
api.splits.keys()
# Out:
# dict_keys(['test_4x10', 'test_2x2', 'test_4x4', 'train', 'val', 'test_8x10', 'test', 'test_2x4'])

# %%
api.get_PIL("test", 3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1636x2180>

# %%
api.get_PIL("test_2x2", 3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=818x1090>

# %%
api.get_PIL("test_2x4", 3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=818x545>

# %%
api.get_PIL("test_4x4", 6)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=409x545>

# %%
api.get_PIL("test_4x10", 6)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=409x218>

# %%
api.get_PIL("test_8x10", 10)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=204x218>
